# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# ======================================
# 1. 讀取 Excel （請修改你的檔案名稱）
# ======================================
df = pd.read_excel("1.K-means-上課範例3-題目.20筆.xlsx")   # <-- 你的 Excel 名稱
df = df[['Age', 'Income']]        # 只取需要欄位

print("原始資料：")
print(df)

# ======================================
# 2. 標準化 Standardization
# ======================================
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df)

scaled_df = pd.DataFrame(scaled_data, columns=['Age_std', 'Income_std'])

# ======================================
# 3. K-means 分群（3 群）
# ======================================
kmeans = KMeans(n_clusters=3, random_state=42)
clusters = kmeans.fit_predict(scaled_df)

df['Cluster'] = clusters  # 將結果加入原資料

print("\n=== 20筆資料的歸屬群組 ===")
print(df)

# ======================================
# 4. 三個群中心（標準化後的 mean 座標）
# ======================================
centers = kmeans.cluster_centers_
centers_df = pd.DataFrame(centers, columns=['Age_std', 'Income_std'])
centers_df.index = ['Group 0', 'Group 1', 'Group 2']

print("\n=== 三個群中心（標準化後） ===")
print(centers_df)

# ======================================
# 5. 描述三群資料特性（以平均值描述）
# ======================================
print("\n=== 三個群組的特性 ===")
for i in range(3):
    group_data = df[df['Cluster'] == i][['Age', 'Income']]
    print(f"\n群組 {i}:")
    print(group_data.describe())

# ======================================
# 6. 畫散佈圖（含群中心）
# ======================================
plt.figure(figsize=(7,6))
plt.scatter(scaled_df['Age_std'], scaled_df['Income_std'], c=clusters, s=80)

# 畫群中心
plt.scatter(centers[:,0], centers[:,1], marker='X', s=200)

plt.title("K-means Clustering (3 Groups)")
plt.xlabel("Age (Standardized)")
plt.ylabel("Income (Standardized)")
plt.grid(True)
plt.show()
